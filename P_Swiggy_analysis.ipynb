# %%
import pandas as pd 
df = pd.read_csv(R"C:\Users\ACER\Desktop\Swiggy\Swiggy_Varanasi.csv")

# %%
df
# Out:
#                            Restaurant Name  \
# 0    Singh's Delight Restaurant(Sunderpur)
# 1                              Burger King
# 2                               McDonald's
# 3                              Aman E Khas
# 4           Mahadev momo and coffee corner
# ..                                     ...
# 662                        The Star Bakery
# 663                        The Live Bakery
# 664                        GO GREEN BAKERY
# 665                             Fresh Cake
# 666                             Ram Bakery
#
#                                  Category  Rating  Cost for two  \
# 0    North Indian,Biryani,Mughlai,Chinese     3.8           350
# 1                      American,Fast Food     4.1           350
# 2                                American     4.0           400
# 3    Mughlai,Biryani,North Indian,Chinese     3.9           350
# 4                                 Chinese     NaN           200
# ...

# %%
pip install pandas-profilling
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pandas-profilling (from versions: none)
# ERROR: No matching distribution found for pandas-profilling

# %%
from pandas_profiling import ProfileReport

prof = ProfileReport(df)
prof.to_file(output_file='swiggyanalysis.html')
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_9456/2057278773.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df['Address'].nunique()
# Out:
# 537

# %%
#667-537
667-0.6*667
# Out:
# 266.8

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.drop('Rating', axis=1), df['Rating'], test_size=0.3, random_state=0)

# %%
y_train
# Out:
# 557    NaN
# 426    NaN
# 132    3.7
# 173    NaN
# 178    NaN
#       ...
# 9      4.1
# 359    NaN
# 192    NaN
# 629    NaN
# 559    3.6
# Name: Rating, Length: 466, dtype: float64

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# %%
type('Rating')
# Out:
# str

# %%
df =df[df['Rating']>=4]

# %%
df.head(10)
# Out:
#                     Restaurant Name  \
# 1                       Burger King
# 2                        McDonald's
# 9                  The Cake Cottage
# 19            Zaika Fresh and Tasty
# 20  Pallavi Baati Chokha Restaurant
# 28                      Hari Vilaas
# 34            Shahi Daya Restaurant
# 35                        Bistro B2
# 38                   Domino's Pizza
# 42                  Behrouz Biryani
#
#                                              Category  Rating  Cost for two  \
# 1                                  American,Fast Food     4.1           350
# 2                                            American     4.0           400
# 9                                              Bakery     4.1           300
# 19                                     Indian,Chinese     4.0           200
# 20                                             Indian     4.1           200
# 28     North Indian,Chinese,Italian,Biryani,Beverages     4.0           400
# ...

# %%
sf = pd.read_csv(R"C:\Users\ACER\Desktop\Buisness_Dataset\india-news-headlines.csv")

# %%
sf.head(30)
# Out:
#     publish_date headline_category  \
# 0       20010102           unknown
# 1       20010102           unknown
# 2       20010102           unknown
# 3       20010102           unknown
# 4       20010102           unknown
# 5       20010102           unknown
# 6       20010102           unknown
# 7       20010102           unknown
# 8       20010102           unknown
# 9       20010102           unknown
# 10      20010102           unknown
# 11      20010102           unknown
# 12      20010102           unknown
# 13      20010102           unknown
# 14      20010102           unknown
# 15      20010102           unknown
# 16      20010102           unknown
# 17      20010102           unknown
# 18      20010102           unknown
# 19      20010102           unknown
# 20      20010102           unknown
# 21      20010102           unknown
# 22      20010102           unknown
# 23      20010102           unknown
# 24      20010102           unknown
# ...
